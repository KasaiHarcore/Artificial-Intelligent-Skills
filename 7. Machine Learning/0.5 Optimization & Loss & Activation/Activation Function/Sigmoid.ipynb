# %% [markdown]
# The ***sigmoid*** activation function was developed by the American mathematician Francis Rosenblatt in the late 1950s as part of his work on artificial neural networks.

# %% [markdown]
# If you learn about machine learning, you will no longer be unfamiliar with the sigmoid function in the logic recovery problem. The sigmoid function has a *nice "S" curve shape*. This is a continuous, feasible function and bounded in the interval (0, 1). The formula of the sigmoid function is as follows:

# %% [markdown]
# $$\sigma(x) = \frac{1}{1 + e^{-x}}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here’s why sigmoid/logistic activation function is one of the most widely used functions:
# - It is commonly used for models where we have to predict the probability as an output. Since probability of anything exists only **between the range of 0 and 1**, sigmoid is the right choice because of its range.
# - The function is differentiable and provides a smooth gradient, i.e., **preventing jumps in output values**. This is represented by an S-shape of the sigmoid activation function.

# %% [markdown]
# The limitations of sigmoid function are discussed below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As we can see from the above Figure, the gradient values are only significant for range -3 to 3, and the graph gets much flatter in other regions.

# %% [markdown]
# It implies that for values greater than 3 or less than -3, the function will **have very small gradients**. As the gradient value approaches zero, the network ceases to learn and suffers from the ***Vanishing gradient problem***.

# %% [markdown]
# The output of the logistic function is not symmetric around zero. So the output of all the neurons will be of the same sign. This makes the training of the neural network more difficult and unstable.
