# %% [markdown]
# ### RNNs và Vanishing Gradient

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Từ cách hoạt động của mô hình RNN trên, thứ tự xử lý các chuỗi sẽ bắt đầu từ ô màu cam, tức nó sẽ bắt đầu từ phần tử đầu tiên của chuỗi. Mỗi ô sẽ nhận đầu vào từ ô trước đó và đầu ra của nó sẽ được truyền vào ô tiếp theo. Điều này giúp mô hình RNN có khả năng nhớ thông tin từ các bước trước đó. Tuy nhiên, mô hình RNN cũng gặp phải một vấn đề là Vanishing Gradient:
# - Theo như ta thấy thì ô màu cam dần dần bị thay thế bởi các ô khác
# - Vì thế phép tính từ ô đầu tiên sẽ không còn nhiều ảnh hưởng đến kết quả cuối cùng, cũng như cost function

# %% [markdown]
# ![image.png](attachment:image.png)
