# %% [markdown]
# # Conditions and Loops
#
# ## Conditional
# - Suppose that you have a group of movies in a dataset, like the one you see here, and you want to only select the movies released after the year 2000. To do this, we’re going to have to rely on a conditional statement. In other words, we need to examine the dataset row by row, and check if the year value is greater than 2000 or not. In R, we can use an “if” statement to accomplish this.
#
# ```R
# if (condition) {
#   # do something (if condition is TRUE)
# } else {
#     # do something else (if condition is FALSE)
# }
# ```
#
# - You will see that how familiar this syntax is if you have used other programming languages before like Python.
#
#
# ## For loops
# - Let's us take an example, where we want to print the numbers from 1 to 5. We can do this using a for loop. In R, we can use a for loop to iterate over a vector, a list, or a data frame. In this case, we want to iterate over a vector of numbers from 1 to 5. We can do this using the colon operator, which is a shortcut for creating a vector of numbers. We can then use the for loop to iterate over the vector and print each number.
#
# ```R
# for (val in vector) {
#   # do something
# }
# ```
#
# - Like python, the loop can be contain some conditional statement, even new vector, list, variable can be created inside the loop.
#
# ```R
# years <- c(1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#            1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#            2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#            2014, 2015, 2016, 2017, 2018, 2019, 2020)
#
# for (year in years) {
#   if (year > 2000) {
#     print(year)
#   } else {
#     print("This year is not greater than 2000")
#   }
# }
# ```
#
# ## While loops
# - While loops are similar to for loops, except that the loop is executed while a certain condition is true. For example, we can use a while loop to print the numbers from 1 to 5. We can do this by first initializing a variable to 1, and then using a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1. We can then use a while loop to print the value of the variable, and then incrementing the variable by 1.
#
# ```R
# i <- 1
#
# while (i <= 5) {
#   print(i)
#   i <- i + 1
# }
# ```
#
# - Same as Python, we can use break and next to control the loop.
#
# ```R
# i <- 1
#
# while (i <= 5) {
#   if (i == 3) {
#     i <- i + 1
#     next # Instead of (continue) in Python
#   }
#   print(i)
#   if (i == 4) {
#     break
#   }
#   i <- i + 1
# }
# ```
#
# - Like for loops, we can define new variables, list, vector, matrix, ... inside. Also the condition can be set to True or False.
